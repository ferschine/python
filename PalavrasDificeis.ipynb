# %% [markdown]
# <a href="https://colab.research.google.com/github/ferschine/python/blob/main/PalavrasDificeis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Palavras Difíceis - SAEB 😰🔮😭

# %% [markdown]
# ![saeb.png](data:image/png;base64,...)
# ![eminem-pointing-to-the-camera-with-question-mark-restored-v0-vllsckakeaya1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #**😰 Enunciado 1:**

# %% [markdown]
# Imagine que você está desenvolvendo uma seção de comentários em uma rede social. Cada comentário terá um contador de curtidas.  Analise o código que demonstra a implementação deste contador usando HTML e JavaScript. Na linha 08 o código descreve que o contador < span id="curtidas" > de curtidas inicia no valor 0. Qual alternativa indica o valor exibido em  após clicar no botão "Curtir" duas vezes?

# %% [markdown]
# **Palavas difíceis:**
#
# * < span id=”curtidas” >;
# * addEventListener;
# * document.getElementByID;
# * numCurtidas.

# %% [markdown]
# #**🔮 Enunciado 2:**

# %% [markdown]
# Em um sistema de estacionamento, o valor cobrado depende do número de horas que o carro ficou estacionado. A cada hora completa, é cobrado R$ 5,00, e o valor total é calculado somente se o tempo for maior que zero. O código a seguir verifica o tempo estacionado e retorna o valor a ser pago:
# Ao chamar a função com o parâmetro horasTotais sendo 3, qual será a saída do código?

# %% [markdown]
# **Palavras difíceis:**
#
# Não tive dificuldade em nenhuma palavra ou nomenclatura dessa questão :)

# %% [markdown]
# #**😭 Enunciado 3:**

# %% [markdown]
# O código JavaScript implementa um contador de curtidas, mas a lógica de atualização está diretamente dentro do addEventListener. Agrupar todas as tarefas necessárias em uma função é considerado uma boa prática neste caso. Para isso, a função deve:

# %% [markdown]
# **Palavras difíceis:**
#
# * addEventListener;
# * parâmetro de entrada;
# * numeroAtual++;
# * document.getElementByID.
